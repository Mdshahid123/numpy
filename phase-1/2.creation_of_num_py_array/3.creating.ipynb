# %% [markdown]
# ## homw work
#
# ##  ques : apart from np.array() and np.arange() what diffrent way we have to create a numoy array

# %%
# using np.Zeroes()

# it will create a array of any diemntion with values zeroes 

# but you have to pass a shape to createa requred dimention

import numpy as np

num_arr_with_zero=np.zeroes((2,3))# it will create a two dimention numpy array with total 6 element 
num_arr_with_zero=np.zeroes((5))# it will create a one  dimention numpy array with 5 elements 
print(num_arr_with_zero)

# %%
# using np.ones()

# it will create a array of any diemntion with values ones

# but you have to pass a shape to createa requred dimention
