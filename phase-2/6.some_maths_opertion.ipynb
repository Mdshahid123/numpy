# %% [markdown]
# ## addition operation

# %% [markdown]
# ## addition operation add the corresponding elements

# %%
# example 1:

import numpy as np 
arr=np.array([10,20,8,12])

print(arr+9)
# Out:
# [19 29 17 21]

# %%
#  example 02 

import numpy as np 
arr1=np.array([10,20,8,12])
arr2=np.array([10,20,30,40])

print(arr1+arr2)
# Out:
# [20 40 38 52]

# %%
# example :03
import numpy as np 
arr1=np.array([
  [10,20,8,12],
  [10,20,8,12],
  [10,20,8,12],
  ])
arr2=np.array([
  [10,20,8,12],
  [10,20,8,12],
  [10,20,8,12],
  ])



print(arr1+arr2)
# Out:
# [[20 40 16 24]
#  [20 40 16 24]
#  [20 40 16 24]]

# %% [markdown]
# # multiplication operation

# %%
import numpy as np 
arr1=np.array([10,20,8,12])


print(arr1*5)
# Out:
# [ 50 100  40  60]

# %%
import numpy as np 
arr1=np.array([10,20,8,12])
arr2=np.array([10,20,8,12])

print(arr1*arr2)
# Out:
# [1. 1. 1. 1.]

# %% [markdown]
# ## divistion operation

# %% [markdown]
# ## dot product of two numpy array
