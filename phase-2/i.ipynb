# %% [markdown]
# ##  SLICING IN NUMPY ARRAY
#
# #### In NumPy, slicing means extracting a part of an array.
#
# #### The basic syntax is:
#
# #### array[start idx  : stop index : step]
# #### start inx → from where to start
# #### stop idx → where to stop (not included)
# #### step → how many positions to jump

# %% [markdown]
# ### 1) Slicing in one-D numpy array

# %%
# slicing a one-D numpy array

import numpy as np
num_arr=np.array([1,2,3,4,10,30,50])

print(f"numpy-array:{num_arr}")


# let's do slicing  with step-1

s1=num_arr[1:4:1] 
print(f" i want slice 2,3,4 : {s1}")

s2=num_arr[3:6]
print(f"i want slice 4,10,30:{s2}")


# do slicing with step 2
s3=num_arr[1:7:2] 
print(f"with two step:{s3}")



# similarly we can get any slice with any step from the given numpy array

# %% [markdown]
# ## question practice

# %%
import numpy as np
num_arr=np.array([10,30,40,80])

s1=num_arr[ : :] # guess output
print(s1)
# Out:
# [10 30 40 80]

# %%
import numpy as np 
num_arr=np.array([10,30,-5,10])

s=num_arr[1: :]

print(s)
# Out:
# array([30, -5, 10])

# %%
import numpy as np
num_arr=num_arr=np.array([6,9,8,10])

s=num_arr[2:4:]
print(s)
# Out:
# [ 8 10]

# %% [markdown]
# ## conclustion
# #### default value of start indx=0,stop_index=size of element and step=1

# %% [markdown]
# ### 2) Slicing  in two dimentinal numpy array
